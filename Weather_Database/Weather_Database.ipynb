# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
        # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 629

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_current_desc = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_current_desc,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ilulissat
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | bredasdorp
# Processing Record 4 of Set 1 | runcu
# Processing Record 5 of Set 1 | hermanus
# Processing Record 6 of Set 1 | avarua
# Processing Record 7 of Set 1 | tiksi
# Processing Record 8 of Set 1 | lebu
# Processing Record 9 of Set 1 | korla
# Processing Record 10 of Set 1 | lagoa
# Processing Record 11 of Set 1 | skibbereen
# Processing Record 12 of Set 1 | busselton
# Processing Record 13 of Set 1 | torbay
# Processing Record 14 of Set 1 | balkanabat
# Processing Record 15 of Set 1 | ancud
# Processing Record 16 of Set 1 | lavrentiya
# Processing Record 17 of Set 1 | pangnirtung
# Processing Record 18 of Set 1 | yar-sale
# Processing Record 19 of Set 1 | toliary
# City not found. Skipping...
# Processing Record 20 of Set 1 | tuim
# Processing Record 21 of Set 1 | cayenne
# Processing Record 22 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 23 of Set 1 | svetlogorsk
# Processing Record 24 of Set 1 | qasigiannguit
# Processing Record 25 of Set 1 | georgetown
# Processing Record 26 of Set 1 | kahului
# Processing Record 27 of Set 1 | kapaa
# Processing Record 28 of Set 1 | orizatlan
# Processing Record 29 of Set 1 | tuktoyaktuk
# Processing Record 30 of Set 1 | port elizabeth
# Processing Record 31 of Set 1 | seryshevo
# Processing Record 32 of Set 1 | yellowknife
# Processing Record 33 of Set 1 | roma
# Processing Record 34 of Set 1 | namibe
# Processing Record 35 of Set 1 | ushuaia
# Processing Record 36 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 37 of Set 1 | poyarkovo
# Processing Record 38 of Set 1 | buchanan
# Processing Record 39 of Set 1 | santiago del estero
# Processing Record 40 of Set 1 | fort william
# Processing Record 41 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 42 of Set 1 | port alfred
# Processing Record 43 of Set 1 | bluff
# Processing Record 44 of Set 1 | longyearbyen
# Processing Record 45 of Set 1 | jamestown
# Processing Record 46 of Set 1 | vostok
# Processing Record 47 of Set 1 | boyolangu
# Processing Record 48 of Set 1 | angoche
# Processing Record 49 of Set 1 | mount gambier
# Processing Record 50 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 1 of Set 2 | victoria
# Processing Record 2 of Set 2 | bairiki
# Processing Record 3 of Set 2 | kodinsk
# Processing Record 4 of Set 2 | albany
# Processing Record 5 of Set 2 | kathmandu
# Processing Record 6 of Set 2 | carmo do rio claro
# Processing Record 7 of Set 2 | mar del plata
# Processing Record 8 of Set 2 | wegorzewo
# Processing Record 9 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 10 of Set 2 | atuona
# Processing Record 11 of Set 2 | chegdomyn
# Processing Record 12 of Set 2 | yarada
# Processing Record 13 of Set 2 | thaton
# Processing Record 14 of Set 2 | sao joao da barra
# Processing Record 15 of Set 2 | oktyabrskoye
# Processing Record 16 of Set 2 | kodiak
# Processing Record 17 of Set 2 | nizhniye sergi
# Processing Record 18 of Set 2 | hilo
# Processing Record 19 of Set 2 | mataura
# Processing Record 20 of Set 2 | saldanha
# Processing Record 21 of Set 2 | najran
# Processing Record 22 of Set 2 | talagang
# Processing Record 23 of Set 2 | butaritari
# Processing Record 24 of Set 2 | hobart
# Processing Record 25 of Set 2 | oriximina
# Processing Record 26 of Set 2 | cherskiy
# Processing Record 27 of Set 2 | bima
# Processing Record 28 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 29 of Set 2 | barrow
# Processing Record 30 of Set 2 | berlevag
# Processing Record 31 of Set 2 | pesaro
# Processing Record 32 of Set 2 | suraabad
# Processing Record 33 of Set 2 | jackson
# Processing Record 34 of Set 2 | genhe
# Processing Record 35 of Set 2 | odienne
# Processing Record 36 of Set 2 | aflu
# City not found. Skipping...
# Processing Record 37 of Set 2 | akyab
# Processing Record 38 of Set 2 | khani
# Processing Record 39 of Set 2 | new norfolk
# Processing Record 40 of Set 2 | muros
# Processing Record 41 of Set 2 | nikolskoye
# Processing Record 42 of Set 2 | diffa
# Processing Record 43 of Set 2 | shar
# Processing Record 44 of Set 2 | punta arenas
# Processing Record 45 of Set 2 | dikson
# Processing Record 46 of Set 2 | castro
# Processing Record 47 of Set 2 | shimoda
# Processing Record 48 of Set 2 | rafaela
# Processing Record 49 of Set 2 | upernavik
# Processing Record 50 of Set 2 | nau
# Processing Record 1 of Set 3 | jiwani
# Processing Record 2 of Set 3 | ribeira grande
# Processing Record 3 of Set 3 | vanimo
# Processing Record 4 of Set 3 | severo-kurilsk
# Processing Record 5 of Set 3 | bengkulu
# Processing Record 6 of Set 3 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 7 of Set 3 | saint-philippe
# Processing Record 8 of Set 3 | osoyoos
# Processing Record 9 of Set 3 | samalaeulu
# City not found. Skipping...
# Processing Record 10 of Set 3 | ondjiva
# Processing Record 11 of Set 3 | olafsvik
# Processing Record 12 of Set 3 | carnarvon
# Processing Record 13 of Set 3 | kalispell
# Processing Record 14 of Set 3 | totolapan
# Processing Record 15 of Set 3 | orlik
# Processing Record 16 of Set 3 | amargosa
# Processing Record 17 of Set 3 | fortuna
# Processing Record 18 of Set 3 | at-bashi
# Processing Record 19 of Set 3 | alofi
# Processing Record 20 of Set 3 | cape town
# Processing Record 21 of Set 3 | kerouane
# Processing Record 22 of Set 3 | beringovskiy
# Processing Record 23 of Set 3 | hihifo
# City not found. Skipping...
# Processing Record 24 of Set 3 | darhan
# Processing Record 25 of Set 3 | ixtapa
# Processing Record 26 of Set 3 | bambous virieux
# Processing Record 27 of Set 3 | poso
# Processing Record 28 of Set 3 | yebaishou
# Processing Record 29 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 30 of Set 3 | impfondo
# Processing Record 31 of Set 3 | oyama
# Processing Record 32 of Set 3 | puerto escondido
# Processing Record 33 of Set 3 | hanko
# Processing Record 34 of Set 3 | gobabis
# Processing Record 35 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 36 of Set 3 | beinamar
# Processing Record 37 of Set 3 | lasa
# Processing Record 38 of Set 3 | ubeda
# Processing Record 39 of Set 3 | bargal
# City not found. Skipping...
# Processing Record 40 of Set 3 | nantucket
# Processing Record 41 of Set 3 | la rioja
# Processing Record 42 of Set 3 | ulcinj
# Processing Record 43 of Set 3 | meulaboh
# Processing Record 44 of Set 3 | bastia
# Processing Record 45 of Set 3 | norman wells
# Processing Record 46 of Set 3 | aquiraz
# Processing Record 47 of Set 3 | chokurdakh
# Processing Record 48 of Set 3 | nhulunbuy
# Processing Record 49 of Set 3 | broome
# Processing Record 50 of Set 3 | eureka
# Processing Record 1 of Set 4 | hasaki
# Processing Record 2 of Set 4 | zhanaozen
# Processing Record 3 of Set 4 | katsuura
# Processing Record 4 of Set 4 | barquisimeto
# Processing Record 5 of Set 4 | maxixe
# Processing Record 6 of Set 4 | tucupita
# Processing Record 7 of Set 4 | kaeo
# Processing Record 8 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 9 of Set 4 | alamos
# Processing Record 10 of Set 4 | launceston
# Processing Record 11 of Set 4 | puerto ayora
# Processing Record 12 of Set 4 | hithadhoo
# Processing Record 13 of Set 4 | narsaq
# Processing Record 14 of Set 4 | thompson
# Processing Record 15 of Set 4 | qaanaaq
# Processing Record 16 of Set 4 | vitim
# Processing Record 17 of Set 4 | imatra
# Processing Record 18 of Set 4 | lysva
# Processing Record 19 of Set 4 | geraldton
# Processing Record 20 of Set 4 | shenjiamen
# Processing Record 21 of Set 4 | kavieng
# Processing Record 22 of Set 4 | tecoanapa
# Processing Record 23 of Set 4 | buon me thuot
# City not found. Skipping...
# Processing Record 24 of Set 4 | perth
# Processing Record 25 of Set 4 | cockburn town
# Processing Record 26 of Set 4 | maragogi
# Processing Record 27 of Set 4 | vaini
# Processing Record 28 of Set 4 | velingara
# Processing Record 29 of Set 4 | airai
# Processing Record 30 of Set 4 | paamiut
# Processing Record 31 of Set 4 | haibowan
# City not found. Skipping...
# Processing Record 32 of Set 4 | viligili
# City not found. Skipping...
# Processing Record 33 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 34 of Set 4 | santiago
# Processing Record 35 of Set 4 | clyde river
# Processing Record 36 of Set 4 | road town
# Processing Record 37 of Set 4 | amazar
# Processing Record 38 of Set 4 | kruisfontein
# Processing Record 39 of Set 4 | cortez
# Processing Record 40 of Set 4 | yangambi
# Processing Record 41 of Set 4 | tasiilaq
# Processing Record 42 of Set 4 | talnakh
# Processing Record 43 of Set 4 | xambioa
# Processing Record 44 of Set 4 | mahebourg
# Processing Record 45 of Set 4 | ishinomaki
# Processing Record 46 of Set 4 | nanortalik
# Processing Record 47 of Set 4 | shagonar
# Processing Record 48 of Set 4 | batticaloa
# Processing Record 49 of Set 4 | teknaf
# Processing Record 50 of Set 4 | burnie
# Processing Record 1 of Set 5 | kedrovyy
# Processing Record 2 of Set 5 | qinhuangdao
# Processing Record 3 of Set 5 | ndele
# Processing Record 4 of Set 5 | grand gaube
# Processing Record 5 of Set 5 | khatanga
# Processing Record 6 of Set 5 | jiquinlaca
# Processing Record 7 of Set 5 | khor
# Processing Record 8 of Set 5 | solovetskiy
# City not found. Skipping...
# Processing Record 9 of Set 5 | dahanu
# Processing Record 10 of Set 5 | constitucion
# Processing Record 11 of Set 5 | karratha
# Processing Record 12 of Set 5 | husavik
# Processing Record 13 of Set 5 | castro-urdiales
# Processing Record 14 of Set 5 | ranong
# Processing Record 15 of Set 5 | bilibino
# Processing Record 16 of Set 5 | dhidhdhoo
# Processing Record 17 of Set 5 | lompoc
# Processing Record 18 of Set 5 | debre tabor
# Processing Record 19 of Set 5 | faanui
# Processing Record 20 of Set 5 | moranbah
# Processing Record 21 of Set 5 | kaduna
# Processing Record 22 of Set 5 | chekhov
# Processing Record 23 of Set 5 | cao bang
# Processing Record 24 of Set 5 | hovd
# Processing Record 25 of Set 5 | salekhard
# Processing Record 26 of Set 5 | ust-ilimsk
# Processing Record 27 of Set 5 | bethel
# Processing Record 28 of Set 5 | suntar
# Processing Record 29 of Set 5 | laguna
# Processing Record 30 of Set 5 | vestmannaeyjar
# Processing Record 31 of Set 5 | kibre mengist
# Processing Record 32 of Set 5 | holalkere
# Processing Record 33 of Set 5 | benjamin aceval
# Processing Record 34 of Set 5 | campoverde
# Processing Record 35 of Set 5 | denpasar
# Processing Record 36 of Set 5 | pisco
# Processing Record 37 of Set 5 | salta
# Processing Record 38 of Set 5 | san carlos de bariloche
# Processing Record 39 of Set 5 | saskylakh
# Processing Record 40 of Set 5 | pokhara
# Processing Record 41 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 42 of Set 5 | hambantota
# Processing Record 43 of Set 5 | cairo
# Processing Record 44 of Set 5 | gornopravdinsk
# Processing Record 45 of Set 5 | maneadero
# Processing Record 46 of Set 5 | gangotri
# City not found. Skipping...
# Processing Record 47 of Set 5 | los llanos de aridane
# Processing Record 48 of Set 5 | northam
# Processing Record 49 of Set 5 | umm kaddadah
# Processing Record 50 of Set 5 | sao felix do xingu
# Processing Record 1 of Set 6 | saint george
# Processing Record 2 of Set 6 | merauke
# Processing Record 3 of Set 6 | arraial do cabo
# Processing Record 4 of Set 6 | bealanana
# Processing Record 5 of Set 6 | hauterive
# Processing Record 6 of Set 6 | pacific grove
# Processing Record 7 of Set 6 | waipawa
# Processing Record 8 of Set 6 | leshukonskoye
# Processing Record 9 of Set 6 | belaya gora
# Processing Record 10 of Set 6 | ostrovnoy
# Processing Record 11 of Set 6 | yuksekova
# Processing Record 12 of Set 6 | ofaqim
# Processing Record 13 of Set 6 | bannu
# Processing Record 14 of Set 6 | nouadhibou
# Processing Record 15 of Set 6 | yasnyy
# Processing Record 16 of Set 6 | talara
# Processing Record 17 of Set 6 | ranot
# Processing Record 18 of Set 6 | mazatlan
# Processing Record 19 of Set 6 | provideniya
# Processing Record 20 of Set 6 | omsukchan
# Processing Record 21 of Set 6 | pevek
# Processing Record 22 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 23 of Set 6 | fortuna foothills
# Processing Record 24 of Set 6 | calvinia
# Processing Record 25 of Set 6 | zhangye
# Processing Record 26 of Set 6 | rumoi
# Processing Record 27 of Set 6 | katherine
# Processing Record 28 of Set 6 | freetown
# Processing Record 29 of Set 6 | flin flon
# Processing Record 30 of Set 6 | salisbury
# Processing Record 31 of Set 6 | bratsk
# Processing Record 32 of Set 6 | desaguadero
# Processing Record 33 of Set 6 | vilyuysk
# Processing Record 34 of Set 6 | marsaxlokk
# Processing Record 35 of Set 6 | awbari
# Processing Record 36 of Set 6 | cidreira
# Processing Record 37 of Set 6 | kollam
# Processing Record 38 of Set 6 | maun
# Processing Record 39 of Set 6 | aklavik
# Processing Record 40 of Set 6 | honggang
# Processing Record 41 of Set 6 | tsienyane
# City not found. Skipping...
# Processing Record 42 of Set 6 | raudeberg
# Processing Record 43 of Set 6 | tshela
# Processing Record 44 of Set 6 | saryozek
# Processing Record 45 of Set 6 | cabo san lucas
# Processing Record 46 of Set 6 | consett
# Processing Record 47 of Set 6 | puerto leguizamo
# Processing Record 48 of Set 6 | listvyanka
# Processing Record 49 of Set 6 | hamilton
# Processing Record 50 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 1 of Set 7 | mayna
# Processing Record 2 of Set 7 | gravelbourg
# Processing Record 3 of Set 7 | lukovetskiy
# Processing Record 4 of Set 7 | guerrero negro
# Processing Record 5 of Set 7 | blagoyevo
# Processing Record 6 of Set 7 | dolbeau
# City not found. Skipping...
# Processing Record 7 of Set 7 | kailua
# Processing Record 8 of Set 7 | naze
# Processing Record 9 of Set 7 | kamenka
# Processing Record 10 of Set 7 | souillac
# Processing Record 11 of Set 7 | san cristobal
# Processing Record 12 of Set 7 | bangassou
# Processing Record 13 of Set 7 | iquitos
# Processing Record 14 of Set 7 | torzhok
# Processing Record 15 of Set 7 | qaqortoq
# Processing Record 16 of Set 7 | havre-saint-pierre
# Processing Record 17 of Set 7 | fare
# Processing Record 18 of Set 7 | sao desiderio
# Processing Record 19 of Set 7 | rawson
# Processing Record 20 of Set 7 | hokitika
# Processing Record 21 of Set 7 | stykkisholmur
# Processing Record 22 of Set 7 | saint-georges
# Processing Record 23 of Set 7 | ornskoldsvik
# Processing Record 24 of Set 7 | lorengau
# Processing Record 25 of Set 7 | berdigestyakh
# Processing Record 26 of Set 7 | nouakchott
# Processing Record 27 of Set 7 | sao filipe
# Processing Record 28 of Set 7 | moa
# Processing Record 29 of Set 7 | bereda
# Processing Record 30 of Set 7 | valdepenas
# Processing Record 31 of Set 7 | benghazi
# Processing Record 32 of Set 7 | irbil
# Processing Record 33 of Set 7 | xichang
# Processing Record 34 of Set 7 | chuy
# Processing Record 35 of Set 7 | mnogovershinnyy
# Processing Record 36 of Set 7 | xiazhen
# Processing Record 37 of Set 7 | kaitangata
# Processing Record 38 of Set 7 | gushikawa
# Processing Record 39 of Set 7 | faya
# Processing Record 40 of Set 7 | ausa
# Processing Record 41 of Set 7 | iqaluit
# Processing Record 42 of Set 7 | taree
# Processing Record 43 of Set 7 | kingman
# Processing Record 44 of Set 7 | kundiawa
# Processing Record 45 of Set 7 | bardiyah
# Processing Record 46 of Set 7 | port lincoln
# Processing Record 47 of Set 7 | plaeng yao
# Processing Record 48 of Set 7 | darab
# Processing Record 49 of Set 7 | ozernovskiy
# Processing Record 50 of Set 7 | sibolga
# Processing Record 1 of Set 8 | lufkin
# Processing Record 2 of Set 8 | rio grande
# Processing Record 3 of Set 8 | tamworth
# Processing Record 4 of Set 8 | lakefield
# Processing Record 5 of Set 8 | hattiesburg
# Processing Record 6 of Set 8 | da lat
# Processing Record 7 of Set 8 | san patricio
# Processing Record 8 of Set 8 | japura
# Processing Record 9 of Set 8 | esna
# Processing Record 10 of Set 8 | zachagansk
# City not found. Skipping...
# Processing Record 11 of Set 8 | dzilam gonzalez
# Processing Record 12 of Set 8 | kloulklubed
# Processing Record 13 of Set 8 | tadine
# Processing Record 14 of Set 8 | touros
# Processing Record 15 of Set 8 | dutlwe
# Processing Record 16 of Set 8 | zhanatas
# City not found. Skipping...
# Processing Record 17 of Set 8 | broken hill
# Processing Record 18 of Set 8 | nalut
# Processing Record 19 of Set 8 | batemans bay
# Processing Record 20 of Set 8 | charters towers
# Processing Record 21 of Set 8 | baherden
# Processing Record 22 of Set 8 | okhotsk
# Processing Record 23 of Set 8 | isangel
# Processing Record 24 of Set 8 | bathsheba
# Processing Record 25 of Set 8 | havelock
# Processing Record 26 of Set 8 | port-gentil
# Processing Record 27 of Set 8 | gamboula
# Processing Record 28 of Set 8 | bud
# Processing Record 29 of Set 8 | haines junction
# Processing Record 30 of Set 8 | chizhou
# Processing Record 31 of Set 8 | terney
# Processing Record 32 of Set 8 | presidencia roque saenz pena
# Processing Record 33 of Set 8 | daru
# Processing Record 34 of Set 8 | muisne
# Processing Record 35 of Set 8 | namatanai
# Processing Record 36 of Set 8 | tralee
# Processing Record 37 of Set 8 | nome
# Processing Record 38 of Set 8 | flinders
# Processing Record 39 of Set 8 | newcastle
# Processing Record 40 of Set 8 | tekkali
# Processing Record 41 of Set 8 | harlingen
# Processing Record 42 of Set 8 | luanda
# Processing Record 43 of Set 8 | azimur
# City not found. Skipping...
# Processing Record 44 of Set 8 | ternate
# Processing Record 45 of Set 8 | lubango
# Processing Record 46 of Set 8 | matias olimpio
# Processing Record 47 of Set 8 | moree
# Processing Record 48 of Set 8 | tuy hoa
# Processing Record 49 of Set 8 | tsaratanana
# Processing Record 50 of Set 8 | zhangjiakou
# Processing Record 1 of Set 9 | kokoda
# Processing Record 2 of Set 9 | bandar-e torkaman
# City not found. Skipping...
# Processing Record 3 of Set 9 | sambava
# Processing Record 4 of Set 9 | kachiry
# Processing Record 5 of Set 9 | leningradskiy
# Processing Record 6 of Set 9 | tukrah
# Processing Record 7 of Set 9 | ust-shonosha
# Processing Record 8 of Set 9 | sola
# Processing Record 9 of Set 9 | hofn
# Processing Record 10 of Set 9 | hami
# Processing Record 11 of Set 9 | udachnyy
# Processing Record 12 of Set 9 | tarko-sale
# Processing Record 13 of Set 9 | maniitsoq
# Processing Record 14 of Set 9 | matagami
# Processing Record 15 of Set 9 | hays
# Processing Record 16 of Set 9 | cermik
# Processing Record 17 of Set 9 | kratovo
# Processing Record 18 of Set 9 | shitanjing
# Processing Record 19 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 20 of Set 9 | vila
# Processing Record 21 of Set 9 | kharod
# Processing Record 22 of Set 9 | tavda
# Processing Record 23 of Set 9 | yulara
# Processing Record 24 of Set 9 | zavodouspenskoye
# Processing Record 25 of Set 9 | galiwinku
# City not found. Skipping...
# Processing Record 26 of Set 9 | appleton
# Processing Record 27 of Set 9 | paka
# Processing Record 28 of Set 9 | tocopilla
# Processing Record 29 of Set 9 | mareeba
# Processing Record 30 of Set 9 | mayumba
# Processing Record 31 of Set 9 | rocha
# Processing Record 32 of Set 9 | juneau
# Processing Record 33 of Set 9 | porto novo
# Processing Record 34 of Set 9 | tyup
# Processing Record 35 of Set 9 | genc
# Processing Record 36 of Set 9 | puerto madryn
# Processing Record 37 of Set 9 | nguiu
# City not found. Skipping...
# Processing Record 38 of Set 9 | chapais
# Processing Record 39 of Set 9 | sayyan
# Processing Record 40 of Set 9 | esperance
# Processing Record 41 of Set 9 | carutapera
# Processing Record 42 of Set 9 | zhezkazgan
# Processing Record 43 of Set 9 | zwedru
# Processing Record 44 of Set 9 | fort morgan
# Processing Record 45 of Set 9 | port keats
# Processing Record 46 of Set 9 | tucuman
# Processing Record 47 of Set 9 | vila velha
# Processing Record 48 of Set 9 | baruun-urt
# Processing Record 49 of Set 9 | sobolevo
# Processing Record 50 of Set 9 | tezu
# Processing Record 1 of Set 10 | wheatley
# Processing Record 2 of Set 10 | polunochnoye
# Processing Record 3 of Set 10 | talgram
# Processing Record 4 of Set 10 | kawalu
# Processing Record 5 of Set 10 | morondava
# Processing Record 6 of Set 10 | fredericksburg
# Processing Record 7 of Set 10 | wanaka
# Processing Record 8 of Set 10 | carberry
# Processing Record 9 of Set 10 | kahramanmaras
# Processing Record 10 of Set 10 | egvekinot
# Processing Record 11 of Set 10 | kasongo-lunda
# Processing Record 12 of Set 10 | darnah
# Processing Record 13 of Set 10 | sorong
# Processing Record 14 of Set 10 | port shepstone
# Processing Record 15 of Set 10 | oktyabrskiy
# Processing Record 16 of Set 10 | coahuayana
# Processing Record 17 of Set 10 | alikalia
# Processing Record 18 of Set 10 | ponta do sol
# Processing Record 19 of Set 10 | maiduguri
# Processing Record 20 of Set 10 | riviere-au-renard
# Processing Record 21 of Set 10 | lincoln
# Processing Record 22 of Set 10 | lexington
# Processing Record 23 of Set 10 | qarqin
# Processing Record 24 of Set 10 | virginia beach
# Processing Record 25 of Set 10 | lixourion
# Processing Record 26 of Set 10 | gweta
# Processing Record 27 of Set 10 | kitui
# Processing Record 28 of Set 10 | la palma
# Processing Record 29 of Set 10 | dukat
# Processing Record 30 of Set 10 | portland
# Processing Record 31 of Set 10 | coihaique
# Processing Record 32 of Set 10 | port hawkesbury
# Processing Record 33 of Set 10 | nova prata
# Processing Record 34 of Set 10 | dunedin
# Processing Record 35 of Set 10 | kulhudhuffushi
# Processing Record 36 of Set 10 | sitka
# Processing Record 37 of Set 10 | vikindu
# Processing Record 38 of Set 10 | guicheng
# City not found. Skipping...
# Processing Record 39 of Set 10 | boca del monte
# Processing Record 40 of Set 10 | labuhan
# Processing Record 41 of Set 10 | mujiayingzi
# Processing Record 42 of Set 10 | lubao
# Processing Record 43 of Set 10 | altagracia de orituco
# Processing Record 44 of Set 10 | grenaa
# Processing Record 45 of Set 10 | socorro
# Processing Record 46 of Set 10 | east london
# Processing Record 47 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 48 of Set 10 | viedma
# Processing Record 49 of Set 10 | scarborough
# Processing Record 50 of Set 10 | phan thiet
# Processing Record 1 of Set 11 | bihariganj
# Processing Record 2 of Set 11 | dalvik
# Processing Record 3 of Set 11 | normandin
# Processing Record 4 of Set 11 | ossora
# Processing Record 5 of Set 11 | stepnyak
# Processing Record 6 of Set 11 | sur
# Processing Record 7 of Set 11 | kadykchan
# City not found. Skipping...
# Processing Record 8 of Set 11 | nemuro
# Processing Record 9 of Set 11 | hinton
# Processing Record 10 of Set 11 | birecik
# Processing Record 11 of Set 11 | biak
# Processing Record 12 of Set 11 | hualmay
# Processing Record 13 of Set 11 | porto santo
# Processing Record 14 of Set 11 | bergen
# Processing Record 15 of Set 11 | umba
# Processing Record 16 of Set 11 | north platte
# Processing Record 17 of Set 11 | tonstad
# Processing Record 18 of Set 11 | medak
# Processing Record 19 of Set 11 | camocim
# Processing Record 20 of Set 11 | komsomolskiy
# Processing Record 21 of Set 11 | borba
# Processing Record 22 of Set 11 | kuusamo
# Processing Record 23 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 24 of Set 11 | sungairaya
# Processing Record 25 of Set 11 | qiongshan
# Processing Record 26 of Set 11 | gandajika
# Processing Record 27 of Set 11 | fukue
# Processing Record 28 of Set 11 | ndola
# Processing Record 29 of Set 11 | ust-charyshskaya pristan
# Processing Record 30 of Set 11 | damietta
# Processing Record 31 of Set 11 | arroyo
# Processing Record 32 of Set 11 | pagudpud
# Processing Record 33 of Set 11 | margate
# Processing Record 34 of Set 11 | talcahuano
# Processing Record 35 of Set 11 | jining
# Processing Record 36 of Set 11 | padang
# Processing Record 37 of Set 11 | gat
# Processing Record 38 of Set 11 | ambulu
# Processing Record 39 of Set 11 | araguatins
# City not found. Skipping...
# Processing Record 40 of Set 11 | mahajanga
# Processing Record 41 of Set 11 | saint anthony
# Processing Record 42 of Set 11 | dingle
# Processing Record 43 of Set 11 | ukiah
# Processing Record 44 of Set 11 | bakchar
# Processing Record 45 of Set 11 | port augusta
# Processing Record 46 of Set 11 | patterson
# Processing Record 47 of Set 11 | mahibadhoo
# Processing Record 48 of Set 11 | san policarpo
# Processing Record 49 of Set 11 | saiha
# Processing Record 50 of Set 11 | anadyr
# Processing Record 1 of Set 12 | novobirilyussy
# Processing Record 2 of Set 12 | jistebnice
# Processing Record 3 of Set 12 | yarmouth
# Processing Record 4 of Set 12 | atar
# Processing Record 5 of Set 12 | kapuskasing
# Processing Record 6 of Set 12 | volchanets
# Processing Record 7 of Set 12 | svetlyy
# Processing Record 8 of Set 12 | magaria
# Processing Record 9 of Set 12 | bandarbeyla
# Processing Record 10 of Set 12 | manyana
# Processing Record 11 of Set 12 | fort nelson
# Processing Record 12 of Set 12 | erzin
# Processing Record 13 of Set 12 | thano bula khan
# City not found. Skipping...
# Processing Record 14 of Set 12 | matay
# Processing Record 15 of Set 12 | lahad datu
# Processing Record 16 of Set 12 | takayama
# Processing Record 17 of Set 12 | trinidad
# Processing Record 18 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 19 of Set 12 | coquimbo
# Processing Record 20 of Set 12 | cururupu
# Processing Record 21 of Set 12 | kerman
# Processing Record 22 of Set 12 | bonaventure
# Processing Record 23 of Set 12 | changji
# Processing Record 24 of Set 12 | yerbogachen
# Processing Record 25 of Set 12 | mvuma
# Processing Record 26 of Set 12 | kajiado
# Processing Record 27 of Set 12 | shubarshi
# Processing Record 28 of Set 12 | port hedland
# Processing Record 29 of Set 12 | sabang
# Processing Record 30 of Set 12 | ambon
# Processing Record 31 of Set 12 | riyadh
# Processing Record 32 of Set 12 | samarai
# Processing Record 33 of Set 12 | wright
# Processing Record 34 of Set 12 | mayo
# Processing Record 35 of Set 12 | lianzhou
# Processing Record 36 of Set 12 | jiddah
# City not found. Skipping...
# Processing Record 37 of Set 12 | sechura
# Processing Record 38 of Set 12 | alotau
# City not found. Skipping...
# Processing Record 39 of Set 12 | gunjur
# Processing Record 40 of Set 12 | orodara
# Processing Record 41 of Set 12 | srednekolymsk
# Processing Record 42 of Set 12 | bambanglipuro
# Processing Record 43 of Set 12 | binga
# Processing Record 44 of Set 12 | urucara
# Processing Record 45 of Set 12 | sikasso
# Processing Record 46 of Set 12 | sinnamary
# Processing Record 47 of Set 12 | bagdarin
# Processing Record 48 of Set 12 | vytegra
# Processing Record 49 of Set 12 | noyabrsk
# Processing Record 50 of Set 12 | kutum
# Processing Record 1 of Set 13 | kupang
# Processing Record 2 of Set 13 | labelle
# Processing Record 3 of Set 13 | klaksvik
# Processing Record 4 of Set 13 | bazhovo
# Processing Record 5 of Set 13 | luderitz
# Processing Record 6 of Set 13 | mandalgovi
# Processing Record 7 of Set 13 | uwayl
# City not found. Skipping...
# Processing Record 8 of Set 13 | jishou
# Processing Record 9 of Set 13 | petrozavodsk
# Processing Record 10 of Set 13 | kiunga
# Processing Record 11 of Set 13 | boguchany
# Processing Record 12 of Set 13 | bay roberts
# Processing Record 13 of Set 13 | zhaoyuan
# Processing Record 14 of Set 13 | tondano
# Processing Record 15 of Set 13 | dubbo
# Processing Record 16 of Set 13 | lynn haven
# Processing Record 17 of Set 13 | svetlopolyansk
# Processing Record 18 of Set 13 | yara
# Processing Record 19 of Set 13 | krasnoselkup
# Processing Record 20 of Set 13 | nizhniy baskunchak
# Processing Record 21 of Set 13 | innisfail
# Processing Record 22 of Set 13 | tulum
# Processing Record 23 of Set 13 | klodzko
# Processing Record 24 of Set 13 | grindavik
# Processing Record 25 of Set 13 | novoagansk
# Processing Record 26 of Set 13 | mokhsogollokh
# Processing Record 27 of Set 13 | cajaruro
# Processing Record 28 of Set 13 | conceicao do araguaia
# Processing Record 29 of Set 13 | chadiza
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 586

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   Ilulissat  69.2167  -51.1000     21.22        68          75       12.66
# 1     Rikitea -23.1203 -134.9692     75.81        75           6       16.69
# 2  Bredasdorp -34.5322   20.0403     72.28        52          40       12.66
# 3       Runcu  45.1167   23.1333     44.37        90         100        2.24
# 4    Hermanus -34.4187   19.2345     72.81        66         100       15.59
# 5      Avarua -21.2078 -159.7750     77.05        83          20       11.50
# 6       Tiksi  71.6872  128.8694    -33.00       100          64        4.74
# 7        Lebu -37.6167  -73.6500     56.43        63           0       17.72
# 8       Korla  41.7597   86.1469     28.24        45           0        0.67
# 9       Lagoa  39.0500  -27.9833     63.68        74           0       14.36
#
#   Country Current Description                 Date
# 0      GL       broken clouds  2021-12-03 12:47:35
# 1      PF           clear sky  2021-12-03 12:47:36
# 2      ZA    scattered clouds  2021-12-03 12:47:36
# 3      RO     overcast clouds  2021-12-03 12:47:36
# 4      ZA     overcast clouds  2021-12-03 12:47:37
# 5      CK          few clouds  2021-12-03 12:47:37
# 6      RU       broken clouds  2021-12-03 12:47:38
# 7      CL           clear sky  2021-12-03 12:47:38
# 8      CN           clear sky  2021-12-03 12:47:38
# 9      PT           clear sky  2021-12-03 12:47:39

# %%
# New column order
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Ilulissat      GL  69.2167  -51.1000     21.22        68          75
# 1     Rikitea      PF -23.1203 -134.9692     75.81        75           6
# 2  Bredasdorp      ZA -34.5322   20.0403     72.28        52          40
# 3       Runcu      RO  45.1167   23.1333     44.37        90         100
# 4    Hermanus      ZA -34.4187   19.2345     72.81        66         100
# 5      Avarua      CK -21.2078 -159.7750     77.05        83          20
# 6       Tiksi      RU  71.6872  128.8694    -33.00       100          64
# 7        Lebu      CL -37.6167  -73.6500     56.43        63           0
# 8       Korla      CN  41.7597   86.1469     28.24        45           0
# 9       Lagoa      PT  39.0500  -27.9833     63.68        74           0
#
#    Wind Speed Current Description
# 0       12.66       broken clouds
# 1       16.69           clear sky
# 2       12.66    scattered clouds
# 3        2.24     overcast clouds
# 4       15.59     overcast clouds
# 5       11.50          few clouds
# 6        4.74       broken clouds
# 7       17.72           clear sky
# 8        0.67           clear sky
# 9       14.36           clear sky

# %%
# Create the output file (CSV).
output_data_file = "weather_database/WeatherPy_Database.csv"
# Export the City_data into the CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
